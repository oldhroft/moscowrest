# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../data/stg/mosdata_dataset1903.csv')

# %%
data.shape
# Out:
# (19556, 14)

# %%
data.TypeObject.value_counts()
# Out:
# кафе                                 7241
# предприятие быстрого обслуживания    3270
# ресторан                             2399
# столовая                             2215
# кафетерий                            1584
# бар                                  1322
# закусочная                            613
# магазин (отдел кулинарии)             467
# буфет                                 445
# Name: TypeObject, dtype: int64

# %%
data.loc[data.Name.str.lower().str.contains('virgin')].Name.iloc[0]
# Out:
# 'Eхtra Virgin'

# %%
'eхtra virgin'.encode('utf-8')
# Out:
# b'e\xd1\x85tra virgin'

# %%
'extra virgin'.encode('utf-8')
# Out:
# b'extra virgin'

# %%
(
    data.loc[data.TypeObject.isin(['кафе', 'ресторан'])]
    .plot.scatter(x='x_coord', y='y_coord', s=.1)
)

plt.grid()
